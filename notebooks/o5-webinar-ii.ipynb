-- %% [markdown]
-- # **Webinar** | Innovative Education in Digital Era
--
-- ### Wed, Apr 19, 4:00 pm - 7:00 pm (GMT+1)
--
-- ![cs4all-consortium-short.png](attachment:1ebb3b52-4cda-48b0-8520-bc2b0db0f35e.png)
--
-- ---

-- %% [markdown]
-- #### ⚠️ **Important**: please start by executing the cell below (put the cursor there and then SHIFT+ENTER).

-- %%
:l ./src/ensico.hs
:m Data.Char
:m Data.List
:opt no-lint

-- %% [markdown]
-- ---
-- ### **Part I** - Transformations **`reverse`**, **`sort`** and **`nub`**

-- %% [markdown]
-- ---
-- ![image.png](attachment:4c1d1011-4398-418f-8fcd-05ee9dac542d.png)

-- %% [markdown]
-- ---
-- ### **Exercises:**

-- %%
[3,3,2,2,9] |> reverse
-- Out:
-- [9,2,2,3,3]

-- %%
[3,3,2,2,9] |> sort
-- Out:
-- [2,2,3,3,9]

-- %%
[3,3,2,2,9] |> nub
-- Out:
-- [3,2,9]

-- %%
[4,1,2,1,1] |> reverse
-- Out:
-- [1,1,2,1,4]

-- %%
[4,1,2,1,1] |> sort
-- Out:
-- [1,1,1,2,4]

-- %%
[4,1,2,1,1] |> nub
-- Out:
-- [4,1,2]

-- %% [markdown]
-- ---
-- ![image.png](attachment:193021a4-bf08-4968-a303-2f55a120aa43.png)

-- %% [markdown]
-- ---
-- ### **Exercises:**

-- %%
[3,5,2,5,1] |> nub
-- Out:
-- [3,5,2,1]

-- %%
[1,0,2,5,4] |> sort
-- Out:
-- [0,1,2,4,5]

-- %%
[1,2,3,3,4] |> sort
-- Out:
-- [1,2,3,3,4]

-- %%
[1,2,3,3,4] |> nub
-- Out:
-- [1,2,3,4]

-- %%
[1,0,2,5,4] |> reverse
-- Out:
-- [4,5,2,0,1]

-- %%
[3,1,5,5,4] |> reverse
-- Out:
-- [4,5,5,1,3]

-- %% [markdown]
-- ---
-- ### **Part II** - Composing transformations

-- %% [markdown]
-- ---
-- ![image.png](attachment:247e1867-3a74-4401-8cb9-5a77dc686bd4.png)

-- %%
[2,5,2,3,1] |> sort |> reverse
-- Out:
-- [5,3,2,2,1]

-- %% [markdown]
-- ---
-- ![image.png](attachment:1ee23585-d2df-4a16-aaf6-c73fc62d2ea2.png)

-- %%
[2,5,2,3,1] |> reverse |> nub
-- Out:
-- [1,3,2,5]

-- %% [markdown]
-- ---

-- %% [markdown]
-- ![image.png](attachment:9669c57d-aa7b-4f1e-b55c-5b4a7dfefbed.png)

-- %%
[4,1,3,1,2] |> reverse |> sort
-- Out:
-- [1,1,2,3,4]

-- %%
[4,1,3,1,2] |> sort |> reverse
-- Out:
-- [4,3,2,1,1]

-- %%
[4,1,3,1,2] |> sort |> nub
-- Out:
-- [1,2,3,4]

-- %%
[4,1,3,1,2] |> nub |> sort
-- Out:
-- [1,2,3,4]

-- %%
[4,1,3,1,2] |> nub |> reverse
-- Out:
-- [2,3,1,4]

-- %%
[4,1,3,1,2] |> reverse |> nub
-- Out:
-- [2,1,3,4]

-- %% [markdown]
-- ---
-- ![image.png](attachment:3677b46f-ee40-4f4b-94fe-2e05fb15b134.png)

-- %%
[5,5,2,1,9] |> sort |> reverse
-- Out:
-- [9,5,5,2,1]

-- %%
[2,1,6,6,2] |> reverse |> nub
-- Out:
-- [2,6,1]

-- %%
[4,7,3,3,0] |> reverse |> sort
-- Out:
-- [0,3,3,4,7]

-- %%
[2,1,6,6,2] |> nub |> reverse
-- Out:
-- [6,1,2]

-- %%
[9,1,2,2,3,1,5] |> reverse |> nub |> reverse
-- Out:
-- [9,2,3,1,5]
